# %%
import numpy as np
import matplotlib as plt
import soundfile as sf
import sounddevice as sd
import librosa 
import IPython.display as ipd
import scipy as sc

# %%
# am 18.01 um generierung gleich langer Signale erweitert

# %%
fs = 44100
u = 1;
for i in range (1, 5+1, 1):
    for j in range (1, 10+1, 1):
        x, samplerate = librosa.load('GuitSigClean_Monophon/Monophon (%d).wav' %i, mono=True, sr=fs)
        x=np.pad(x,(0,4*fs-len(x)),'constant')
        h, samplerate = librosa.load('IR_Trial/IR_%d.wav' %j, mono=True, sr=fs)
        h=np.pad(x,(0,fs-len(h)),'constant')
        conv = sc.signal.fftconvolve(x, h, mode='full')
        sf.write('./Convolved_Sig/test2/IR_%d/conv_%d_sig_%d_IR_%d.wav' %(j,u,i,j), conv, fs)
        u += 1
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\SEBAST~1.BER\AppData\Local\Temp/ipykernel_18020/1949565611.py in <module>
#       8         h=np.pad(x,(0,fs-len(h)),'constant')
#       9         conv = sc.signal.fftconvolve(x, h, mode='full')
# ---> 10         sf.write('./Convolved_Sig/test2/IR_%d/conv_%d_sig_%d_IR_%d.wav' %(j,u,i,j), conv, fs)
#      11         u += 1
#
# ~\Anaconda3\lib\site-packages\soundfile.py in write(file, data, samplerate, subtype, endian, format, closefd)
#     312     else:
#     313         channels = data.shape[1]
# --> 314     with SoundFile(file, 'w', samplerate, channels,
#     315                    subtype, endian, format, closefd) as f:
#     316         f.write(data)
#
# ~\Anaconda3\lib\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
# ...
